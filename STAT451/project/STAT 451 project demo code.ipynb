# %%
# %load_ext watermark
# %watermark  -d -u -a "Shihao Yang, Yifan Zhang, Kexiao Zhu" -v -p numpy,scipy,matplotlib,sklearn
# Out:
# Author: Shihao Yang, Yifan Zhang, Kexiao Zhu
#
# Last updated: 2021-12-09
#
# Python implementation: CPython
# Python version       : 3.8.8
# IPython version      : 7.22.0
#
# numpy     : 1.20.1
# scipy     : 1.6.2
# matplotlib: 3.3.4
# sklearn   : 0.24.1

# %% [markdown]
# # Data Processing

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("winequalityN.csv")
print(df.head())
print(df.info())
print(df.describe())
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB
# None
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
label_list = []
labels_map = {
    "white": 0,
    "red": 1}
for i in range(len(df)):
    label_list.append(labels_map[df["type"][i]])
df["type"] = label_list

# %%
labels_map = {
    10: 'high',
    9: 'high',
    8: 'high',
    7: 'medium',
    6: 'medium',
    5: 'medium',
    4: 'low',
    3: 'low',
    2: 'low',
    1: 'low'
}

# %%
df['quality'] = df['quality'].map(labels_map)

# %%
labels_map = {
    "low": 0,
    "medium": 1,
    "high": 2
}

# %%
label_list2 = []
for i in range(len(df)):
    label_list2.append(labels_map[df["quality"][i]])
df["label"] = label_list2
df = df.drop(columns=['quality'])
# df = df.dropna()
df = df.fillna(df.mean())#fill the na value with the overall mean

# %%
df.head()
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     0            7.0              0.27         0.36            20.7
# 1     0            6.3              0.30         0.34             1.6
# 2     0            8.1              0.28         0.40             6.9
# 3     0            7.2              0.23         0.32             8.5
# 4     0            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  label
# 0       0.45      8.8      1
# 1       0.49      9.5      1
# 2       0.44     10.1      1
# 3       0.40      9.9      1
# 4       0.40      9.9      1

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from numpy import set_printoptions
from sklearn.ensemble import ExtraTreesClassifier
# load data
array = df.values
X = array[:,0:12]
Y = array[:,12]
# feature extraction
model = ExtraTreesClassifier(n_estimators=10)
model.fit(X, Y)
print(model.feature_importances_)
# Out:
# [0.00720301 0.08935301 0.10583977 0.08544128 0.09136248 0.0837232
#  0.10056779 0.0857362  0.08535983 0.08828823 0.08492958 0.09219562]

# %%
vars = np.array(['type','fixed acidity',"volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol"])
for name, importance in zip(vars, model.feature_importances_):
     print(name, "=", importance)
# Out:
# type = 0.007203014010157194
# fixed acidity = 0.08935300676479743
# volatile acidity = 0.10583976709965945
# citric acid = 0.08544127974367903
# residual sugar = 0.09136248397313305
# chlorides = 0.08372320119157614
# free sulfur dioxide = 0.10056778540679039
# total sulfur dioxide = 0.08573620185913808
# density = 0.08535982950592506
# pH = 0.08828823005244045
# sulphates = 0.08492957556734064
# alcohol = 0.0921956248253632

# %% [markdown]
# As we can see from above feature importance, we can exclude the wine type since it is the least important feature among others.

# %%
# imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
# data = df.values
# data = imputer.fit_transform(df.values)
# data
df = df.dropna()
df = df.drop(columns=['type'])

X = df[['fixed acidity',"volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol"]].values
y = df['label'].values

# %% [markdown]
# # Model Training

# %%
from sklearn import tree
from sklearn import metrics
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)
print('X_train.shape:', X_train.shape)
print('y_train.shape:', y_train.shape)
print('X_test.shape:', X_test.shape)
print('y_test.shape:', y_test.shape)
# Out:
# X_train.shape: (4547, 11)
# y_train.shape: (4547,)
# X_test.shape: (1950, 11)
# y_test.shape: (1950,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
lr_score=lr.score(X_test,y_test)

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(X_train,y_train)
svm=svm.score(X_test,y_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=100, random_state = 10)
rf.fit(X_train,y_train)
rf_score = rf.score(X_test,y_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
knn_score=knn.score(X_test,y_test)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
dt=dt.score(X_test,y_test)

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_train,y_train)
nb=nb.score(X_test,y_test)

# %%
from sklearn.ensemble import ExtraTreesClassifier
# extra tree
forest = ExtraTreesClassifier(n_estimators=100, random_state = 3)

forest.fit(X_train, y_train)

extra_tree_score = forest.score(X_test, y_test)

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(random_state=123)
ada.fit(X_train, y_train)
ada_score = ada.score(X_test, y_test)

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
hist = HistGradientBoostingClassifier(random_state=123)
hist.fit(X_train, y_train)
hist_score = hist.score(X_test, y_test)

# %% [markdown]
# # Grid Search for Decision Tree and KNN

# %%
from sklearn.model_selection import GridSearchCV
clf = DecisionTreeClassifier(random_state=123)

params =  {
    'min_samples_split': [2, 3, 4, 5, 10, 20, 50],
    'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 50, None],
    'criterion': ['gini','entropy']
}


grid = GridSearchCV(estimator=clf,
                    param_grid=params,
                    cv=10,
                    n_jobs=1,
                    verbose=2)

grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 140 candidates, totalling 1400 fits
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=1, min_samples_split=50; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=50; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=50; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=4, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=50; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=3; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=4; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=20; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=15, min_samples_split=5; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=15, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END .criterion=gini, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=50, min_samples_split=5; total time=   0.0s
# ...
# [CV] END criterion=entropy, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=20, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=3; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=4; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=50; total time=   0.0s
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=123),
#              n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 50, None],
#                          'min_samples_split': [2, 3, 4, 5, 10, 20, 50]},
#              verbose=2)

# %%
grid_search_dt = grid.best_score_

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 10}

# %%
from matplotlib import pyplot as plt
from matplotlib import pyplot as plt
all_train_acc = []
all_train_acc_2 = []
all_hyperparam = []


for i in range(1, 50):
    tree = DecisionTreeClassifier(criterion = 'gini', max_depth=i, random_state=1)
    tree.fit(X_train, y_train)
    train_acc = tree.score(X_train, y_train)
    
    tree2 = DecisionTreeClassifier(criterion = 'entropy',max_depth=i, random_state=1)
    tree2.fit(X_train, y_train)
    train2_acc = tree2.score(X_train, y_train)
    
    all_train_acc.append(train_acc*100)
    all_train_acc_2.append(train2_acc*100)
    all_hyperparam.append(i)
    
plt.plot(all_hyperparam, all_train_acc, label='gini')
plt.plot(all_hyperparam, all_train_acc_2, ls='--', label='entropy')
plt.xlabel('max_depth')
plt.ylabel('Accuracy in %')
plt.legend()
plt.show()

# %%
all_train_acc = []
all_train_acc_2 = []
all_hyperparam = []


for i in range(2, 50):
    tree = DecisionTreeClassifier(criterion = 'gini', min_samples_split=i, random_state=1)
    tree.fit(X_train, y_train)
    train_acc = tree.score(X_train, y_train)
    
    tree2 = DecisionTreeClassifier(criterion = 'entropy',min_samples_split=i, random_state=1)
    tree2.fit(X_train, y_train)
    train2_acc = tree2.score(X_train, y_train)
    
    all_train_acc.append(train_acc*100)
    all_train_acc_2.append(train2_acc*100)
    all_hyperparam.append(i)
    
plt.plot(all_hyperparam, all_train_acc, label='gini')
plt.plot(all_hyperparam, all_train_acc_2, ls='--', label='entropy')
plt.xlabel('min_samples_split')
plt.ylabel('Accuracy in %')
plt.legend()
plt.show()

# %%
param_grid = {'n_neighbors': [1, 3, 5, 7, 9, 11, 13]}

gs = GridSearchCV(estimator=knn,
                  param_grid=param_grid,
                  refit=True,
                  cv=10,
                  n_jobs=-1)

gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(n_neighbors=9), n_jobs=-1,
#              param_grid={'n_neighbors': [1, 3, 5, 7, 9, 11, 13]})

# %%
grid_search_knn = gs.best_score_

# %%
gs.best_params_
# Out:
# {'n_neighbors': 9}

# %%
from matplotlib import pyplot as plt
all_train_acc = []
all_hyperparam = []


for i in range(1, 15):
    tree = KNeighborsClassifier(n_neighbors=i)
    tree.fit(X_train, y_train)
    train_acc = tree.score(X_train, y_train)
    
    all_train_acc.append(train_acc*100)
    all_hyperparam.append(i)
    
plt.plot(all_hyperparam, all_train_acc, label='train')
plt.xlabel('K')
plt.ylabel('Accuracy in %')
plt.legend()
plt.show()

# %%
clf = RandomForestClassifier(n_estimators=100, random_state = 10)

params =  {
    'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 50, None],
    'criterion': ['gini','entropy']
}


grid_rf = GridSearchCV(estimator=clf,
                    param_grid=params,
                    cv=10,
                    n_jobs=1,
                    verbose=2)

grid_rf.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.1s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.3s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.4s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.4s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.4s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.4s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.4s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.4s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.4s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.4s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.5s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.1s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.5s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.4s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.5s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.5s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.5s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.5s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.4s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.5s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.5s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.5s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.4s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.4s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.5s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.5s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.5s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.5s
# GridSearchCV(cv=10, estimator=RandomForestClassifier(random_state=10), n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 50, None]},
#              verbose=2)

# %%
rfg_score = grid_rf.best_score_

# %%
grid_rf.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 50}

# %%
from matplotlib import pyplot as plt
from matplotlib import pyplot as plt
all_train_acc = []
all_train_acc_2 = []
all_hyperparam = []


for i in range(1, 50):
    tree = RandomForestClassifier(criterion = 'gini', max_depth=i, random_state=1)
    tree.fit(X_train, y_train)
    train_acc = tree.score(X_train, y_train)
    
    tree2 = RandomForestClassifier(criterion = 'entropy',max_depth=i, random_state=1)
    tree2.fit(X_train, y_train)
    train2_acc = tree2.score(X_train, y_train)
    
    all_train_acc.append(train_acc*100)
    all_train_acc_2.append(train2_acc*100)
    all_hyperparam.append(i)
    
plt.plot(all_hyperparam, all_train_acc, label='gini')
plt.plot(all_hyperparam, all_train_acc_2, ls='--', label='entropy')
plt.xlabel('max_depth')
plt.ylabel('Accuracy in %')
plt.legend()
plt.show()

# %%
clf = ExtraTreesClassifier(n_estimators=100)

params =  {
    'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 50, None],
    'criterion': ['gini','entropy']
}


grid_et = GridSearchCV(estimator=clf,
                    param_grid=params,
                    cv=10,
                    n_jobs=1,
                    verbose=2)

grid_et.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=1; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=2; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=3; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=4; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END ........................criterion=gini, max_depth=5; total time=   0.0s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=10; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=15; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.1s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=20; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .......................criterion=gini, max_depth=50; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=gini, max_depth=None; total time=   0.2s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=1; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=2; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=3; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=4; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END .....................criterion=entropy, max_depth=5; total time=   0.0s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=10; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=15; total time=   0.1s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=20; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ....................criterion=entropy, max_depth=50; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# [CV] END ..................criterion=entropy, max_depth=None; total time=   0.2s
# GridSearchCV(cv=10, estimator=ExtraTreesClassifier(), n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 50, None]},
#              verbose=2)

# %%
etg_score = grid_et.best_score_

# %%
grid_et.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 20}

# %%
etg_score
# Out:
# 0.9450200900421166

# %%
all_train_acc = []
all_train_acc_2 = []
all_hyperparam = []


for i in range(1, 50):
    tree = ExtraTreesClassifier(criterion = 'gini', max_depth=i, random_state=1)
    tree.fit(X_train, y_train)
    train_acc = tree.score(X_train, y_train)
    
    tree2 = ExtraTreesClassifier(criterion = 'entropy',max_depth=i, random_state=1)
    tree2.fit(X_train, y_train)
    train2_acc = tree2.score(X_train, y_train)
    
    all_train_acc.append(train_acc*100)
    all_train_acc_2.append(train2_acc*100)
    all_hyperparam.append(i)
    
plt.plot(all_hyperparam, all_train_acc, label='gini')
plt.plot(all_hyperparam, all_train_acc_2, ls='--', label='entropy')
plt.xlabel('max_depth')
plt.ylabel('Accuracy in %')
plt.legend()
plt.show()

# %% [markdown]
# # Table of Model Scores - 1

# %%
models = pd.DataFrame({
    'Model': ['Linear Regression', 'KNN', 'SVM', 
              'Random Forest', 'Naive Bayes', 'Decision Tree',
             'Extra Tree','Ada Boosting', 'Hist Gradient Boosting', 'Decision Tree with Grid Search',
             'KNN with Grid Search', 'Random Forest after Grid Search', 'Extra Tree after Grid Search'],
    'Score': [lr_score,knn_score,svm,rf_score,nb,dt, extra_tree_score, ada_score, hist_score, grid_search_dt, grid_search_knn, rfg_score, etg_score]})

# %%
models.sort_values(by='Score', ascending=False)
# Out:
#                               Model     Score
# 12     Extra Tree after Grid Search  0.945020
# 11  Random Forest after Grid Search  0.944140
# 3                     Random Forest  0.941026
# 6                        Extra Tree  0.941026
# 8            Hist Gradient Boosting  0.939487
# 9    Decision Tree with Grid Search  0.932044
# 2                               SVM  0.931795
# 10             KNN with Grid Search  0.931384
# 1                               KNN  0.925641
# 5                     Decision Tree  0.896410
# 7                      Ada Boosting  0.894359
# 4                       Naive Bayes  0.836410
# 0                 Linear Regression  0.060398

# %% [markdown]
# # Ensemble Methods

# %% [markdown]
# Based on the table above, we can choose some models with higher scores to use some ensemble methods.

# %%
from mlxtend.classifier import EnsembleVoteClassifier
# Majority Voting
clf1 = RandomForestClassifier(n_estimators=100, random_state = 2)
clf2 = ExtraTreesClassifier(n_estimators=100, random_state=1)
clf3 = HistGradientBoostingClassifier(random_state=123)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3], weights=[1, 1, 1])

labels = ['Classifier 1', 'Classifier 2', 'Classifier 3', 'Ensemble']
for clf, label in zip([clf1, clf2, clf3, eclf], labels):

    clf.fit(X_train, y_train)
    print("Train Accuracy: %0.2f [%s]" % (clf.score(X_train, y_train), label))
    
vote_score = eclf.score(X_test, y_test)
# Out:
# Train Accuracy: 1.00 [Classifier 1]
# Train Accuracy: 1.00 [Classifier 2]
# Train Accuracy: 1.00 [Classifier 3]
# Train Accuracy: 1.00 [Ensemble]

# %%
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
# BAGGING
forest = RandomForestClassifier(n_estimators=100)


bag = BaggingClassifier(base_estimator=forest,
                        n_estimators=500,
                        oob_score=True,
                        bootstrap=True,
                        bootstrap_features=False,
                        n_jobs=1,
                        random_state=1)

bag.fit(X_train, y_train)
bag_score = bag.score(X_test, y_test)

# %%
# stacking
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import StackingClassifier


clf1 = DecisionTreeClassifier(criterion = 'gini', max_depth = 4, min_samples_split= 2)
clf2 = RandomForestClassifier(random_state=123)
clf3 = HistGradientBoostingClassifier(random_state=123)
clf4 = ExtraTreesClassifier(n_estimators=100)

lr = LogisticRegression(random_state=123, max_iter=1000)

estimators = [('clf1', clf1),
              ('clf2', clf2),
              ('clf3', clf3),
              ('clf4', clf4)]

sclf = StackingClassifier(estimators=estimators, 
                          final_estimator=lr, 
                          cv=10)


sclf.fit(X_train, y_train)
stacking_score = sclf.score(X_test, y_test)

# %%
# stack_method{‘auto’, ‘predict_proba’, ‘decision_function’, ‘predict’}, default=’auto’
from mlxtend.classifier import StackingCVClassifier


sclf = StackingCVClassifier(classifiers=[clf1, clf2, clf3, clf4], 
                            meta_classifier=lr, 
                            use_probas=True, # changed
                            drop_proba_col='last',
                            #use_features_in_secondary=True,
                            cv=10,
                            random_state=123)


sclf.fit(X_train, y_train)
stack_cv_score = sclf.score(X_test, y_test)

# %% [markdown]
# # Table of Model Scores - 2

# %%
models = pd.DataFrame({
    'Model': ['Linear Regression', 'KNN', 'SVM', 
              'Random Forest', 'Naive Bayes', 'Decision Tree',
             'Extra Tree','Ada Boosting', 'Hist Gradient Boosting', 'Decision Tree with Grid Search',
             'KNN with Grid Search', 'Bagging', 'Stacking', 'Stacking CV', 'Majority Voting', 'Random Forest after Grid Search', 'Extra Tree after Grid Search'],
    'Score': [lr_score,knn_score,svm,rf_score,nb,dt, extra_tree_score, ada_score, hist_score, grid_search_dt, grid_search_knn, bag_score, stacking_score, stack_cv_score, vote_score,  rfg_score, etg_score]})

# %%
models.sort_values(by='Score', ascending=False)
# Out:
#                               Model     Score
# 16     Extra Tree after Grid Search  0.945020
# 15  Random Forest after Grid Search  0.944140
# 3                     Random Forest  0.941026
# 14                  Majority Voting  0.941026
# 6                        Extra Tree  0.941026
# 12                         Stacking  0.940513
# 13                      Stacking CV  0.940000
# 8            Hist Gradient Boosting  0.939487
# 11                          Bagging  0.935897
# 9    Decision Tree with Grid Search  0.932044
# 2                               SVM  0.931795
# 10             KNN with Grid Search  0.931384
# 1                               KNN  0.925641
# 5                     Decision Tree  0.896410
# 7                      Ada Boosting  0.894359
# 4                       Naive Bayes  0.836410
# 0                 Linear Regression  0.060398

# %% [markdown]
# # Test our model in another Data Set

# %%
url = 'https://raw.githubusercontent.com/Hawk9808/STAT-451-project-group/main/winequality-red.csv'
df_test = pd.read_csv(url, error_bad_lines=False)
# df_test.head()
# df_test.info()

# %%
labels_map = {
    10: 'high',
    9: 'high',
    8: 'high',
    7: 'medium',
    6: 'medium',
    5: 'medium',
    4: 'low',
    3: 'low',
    2: 'low',
    1: 'low'
}
df_test['quality'] = df_test['quality'].map(labels_map)
labels_map = {
    "low": 0,
    "medium": 1,
    "high": 2
}
label_list2 = []
for i in range(len(df_test)):
    label_list2.append(labels_map[df_test["quality"][i]])
df_test["label"] = label_list2

df_test = df_test.drop(columns=['quality'])
df_test = df_test.fillna(df.mean())#fill the na value with the overall mean
df_test.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  label
# 0      9.4      1
# 1      9.8      1
# 2      9.8      1
# 3      9.8      1
# 4      9.4      1

# %%
X = df_test[['fixed acidity',"volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol"]].values
y = df_test['label'].values

rf=RandomForestClassifier(n_estimators=100)
rf.fit(X_train,y_train)
rf_score=rf.score(X,y)

print(f"Test Accuracy: {100*rf_score:0.2f}%")
# Out:
# Test Accuracy: 98.44%

# %%
forest = ExtraTreesClassifier(n_estimators=100)
forest.fit(X_train, y_train)
extra_tree_score = forest.score(X, y)
print(f"Test Accuracy: {100*extra_tree_score:0.2f}%")
# Out:
# Test Accuracy: 98.50%

# %% [markdown]
# # Feature Importance Analysis

# %%
# random forest
vars = np.array(['fixed acidity',"volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol"])
for name, importance in zip(vars, rf.feature_importances_):
     print(name, "=", importance)
# Out:
# fixed acidity = 0.0770918136084838
# volatile acidity = 0.11205544059044016
# citric acid = 0.07821318305164139
# residual sugar = 0.09151143487449132
# chlorides = 0.0818608362873055
# free sulfur dioxide = 0.11287176206261305
# total sulfur dioxide = 0.0994668172090873
# density = 0.09369787670532347
# pH = 0.08650998368600064
# sulphates = 0.08777356981662543
# alcohol = 0.07894728210798807

# %%
# plot the feature importance
from matplotlib import pyplot as plt
importances = rf.feature_importances_
indices = np.argsort(importances)
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [vars[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# extra trees
for name, importance in zip(vars, forest.feature_importances_):
     print(name, "=", importance)
# Out:
# fixed acidity = 0.08238486638294501
# volatile acidity = 0.10370121341350227
# citric acid = 0.08415120525132389
# residual sugar = 0.0887028642227417
# chlorides = 0.08532863834581955
# free sulfur dioxide = 0.10873568476553817
# total sulfur dioxide = 0.09227597365946609
# density = 0.08528665876870832
# pH = 0.0858941052809568
# sulphates = 0.08859630553514286
# alcohol = 0.09494248437385533

# %%
# plot the feature importance
from matplotlib import pyplot as plt
importances = forest.feature_importances_
indices = np.argsort(importances)
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [vars[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
